# %%
import pandas as pd
import numpy as np
import json
from collections import Counter

# %% [markdown]
# ## Take a look at the input data

# %%
input_data = 'supplier_car.json'

#read input json file, take care of the encoding!
with open(input_data, encoding='utf-8') as f:
    df = pd.DataFrame([json.loads(line) for line in f.readlines()])

# %%
df.head()
# Out:
#        ID       MakeText              TypeName  \
# 0   976.0  MERCEDES-BENZ               McLaren
# 1  1059.0  MERCEDES-BENZ    ML 350 Inspiration
# 2   524.0           AUDI  S6 Avant quattro 4.2
# 3   608.0           SAAB   9-3 2.0i-16 TS Aero
# 4   726.0        PORSCHE      911 Turbo Cabrio
#
#                        TypeNameFull ModelText         ModelTypeText  \
# 0         MERCEDES-BENZ SLR McLaren       SLR           SLR McLaren
# 1  MERCEDES-BENZ ML 350 Inspiration    ML 350    ML 350 Inspiration
# 2         AUDI S6 Avant quattro 4.2        S6  S6 Avant quattro 4.2
# 3          SAAB 9-3 2.0i-16 TS Aero       9-3   9-3 2.0i-16 TS Aero
# 4          PORSCHE 911 Turbo Cabrio       911      911 Turbo Cabrio
#
#   Attribute Names Attribute Values                             entity_id
# 0           Seats                2  0001fda6-192b-46a8-bc08-0e833f904eed
# 1              Hp              235  00107c2d-0071-4475-88f0-810133638b7e
# 2    FuelTypeText           Benzin  00126794-a8ef-48fe-93d6-43cfc69fbfb6
# 3             Ccm             1985  00182529-1bf7-4f93-89fa-2e8e634b2c9d
# 4   BodyColorText     schwarz mét.  002d30c2-43f6-4905-868f-160dbc445c56

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21906 entries, 0 to 21905
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                21906 non-null  object
#  1   MakeText          21906 non-null  object
#  2   TypeName          21906 non-null  object
#  3   TypeNameFull      21906 non-null  object
#  4   ModelText         20957 non-null  object
#  5   ModelTypeText     21906 non-null  object
#  6   Attribute Names   21906 non-null  object
#  7   Attribute Values  21906 non-null  object
#  8   entity_id         21906 non-null  object
# dtypes: object(9)
# memory usage: 1.5+ MB

# %%
#convert ID column to numeric type and sort it
df.ID = pd.to_numeric(df.ID)
df = df.sort_values("ID")

# %%
df.head(60)
# Out:
#         ID       MakeText                   TypeName  \
# 3622   1.0  MERCEDES-BENZ     E 320 Elégance 4-Matic
# 8139   1.0  MERCEDES-BENZ     E 320 Elégance 4-Matic
# 10902  1.0  MERCEDES-BENZ     E 320 Elégance 4-Matic
# 10374  1.0  MERCEDES-BENZ     E 320 Elégance 4-Matic
# 16139  1.0  MERCEDES-BENZ     E 320 Elégance 4-Matic
# 14900  1.0  MERCEDES-BENZ     E 320 Elégance 4-Matic
# 19538  1.0  MERCEDES-BENZ     E 320 Elégance 4-Matic
# 7573   1.0  MERCEDES-BENZ     E 320 Elégance 4-Matic
# 20141  1.0  MERCEDES-BENZ     E 320 Elégance 4-Matic
# 6027   1.0  MERCEDES-BENZ     E 320 Elégance 4-Matic
# 18578  1.0  MERCEDES-BENZ     E 320 Elégance 4-Matic
# 4577   1.0  MERCEDES-BENZ     E 320 Elégance 4-Matic
# 4364   1.0  MERCEDES-BENZ     E 320 Elégance 4-Matic
# 16778  1.0  MERCEDES-BENZ     E 320 Elégance 4-Matic
# 9760   1.0  MERCEDES-BENZ     E 320 Elégance 4-Matic
# 5931   1.0  MERCEDES-BENZ     E 320 Elégance 4-Matic
# 10936  1.0  MERCEDES-BENZ     E 320 Elégance 4-Matic
# 21164  1.0  MERCEDES-BENZ     E 320 Elégance 4-Matic
# 5272   1.0  MERCEDES-BENZ     E 320 Elégance 4-Matic
# 21773  2.0           AUDI  RS6 Avant 5.0 V10 quattro
# 17262  2.0           AUDI  RS6 Avant 5.0 V10 quattro
# 5033   2.0           AUDI  RS6 Avant 5.0 V10 quattro
# 2993   2.0           AUDI  RS6 Avant 5.0 V10 quattro
# 1613   2.0           AUDI  RS6 Avant 5.0 V10 quattro
# 5696   2.0           AUDI  RS6 Avant 5.0 V10 quattro
# 1188   2.0           AUDI  RS6 Avant 5.0 V10 quattro
# 10998  2.0           AUDI  RS6 Avant 5.0 V10 quattro
# 4020   2.0           AUDI  RS6 Avant 5.0 V10 quattro
# 17751  2.0           AUDI  RS6 Avant 5.0 V10 quattro
# 19498  2.0           AUDI  RS6 Avant 5.0 V10 quattro
# 12557  2.0           AUDI  RS6 Avant 5.0 V10 quattro
# 10620  2.0           AUDI  RS6 Avant 5.0 V10 quattro
# 10794  2.0           AUDI  RS6 Avant 5.0 V10 quattro
# 6316   2.0           AUDI  RS6 Avant 5.0 V10 quattro
# 10043  2.0           AUDI  RS6 Avant 5.0 V10 quattro
# 11363  2.0           AUDI  RS6 Avant 5.0 V10 quattro
# 11584  2.0           AUDI  RS6 Avant 5.0 V10 quattro
# 9386   2.0           AUDI  RS6 Avant 5.0 V10 quattro
# 1220   3.0           AUDI          RS6 Avant quattro
# 18137  3.0           AUDI          RS6 Avant quattro
# 19250  3.0           AUDI          RS6 Avant quattro
# 19725  3.0           AUDI          RS6 Avant quattro
# 21456  3.0           AUDI          RS6 Avant quattro
# 1375   3.0           AUDI          RS6 Avant quattro
# 20198  3.0           AUDI          RS6 Avant quattro
# 21434  3.0           AUDI          RS6 Avant quattro
# 6027      E 320 Elégance 4-Matic                  Doors                    4
# 18578     E 320 Elégance 4-Matic                  Seats                    5
# 4577      E 320 Elégance 4-Matic      ConditionTypeText             Occasion
# 4364      E 320 Elégance 4-Matic   TransmissionTypeText              Automat
# 16778     E 320 Elégance 4-Matic           FuelTypeText               Benzin
# 9760      E 320 Elégance 4-Matic           FirstRegYear                 1999
# 5931      E 320 Elégance 4-Matic                   City               Zuzwil
# 10936     E 320 Elégance 4-Matic          FirstRegMonth                    1
# 21164     E 320 Elégance 4-Matic        Co2EmissionText             275 g/km
# 5272      E 320 Elégance 4-Matic          DriveTypeText               Allrad
# 21773  RS6 Avant 5.0 V10 quattro           FirstRegYear                 2008
# 17262  RS6 Avant 5.0 V10 quattro          BodyColorText            anthrazit
# 5033   RS6 Avant 5.0 V10 quattro                   City               Zuzwil
# 2993   RS6 Avant 5.0 V10 quattro   ConsumptionTotalText         14.0 l/100km
# 1613   RS6 Avant 5.0 V10 quattro                     Hp                  580
# 5696   RS6 Avant 5.0 V10 quattro      InteriorColorText                 null
# 1188   RS6 Avant 5.0 V10 quattro        Co2EmissionText             333 g/km
# 10998  RS6 Avant 5.0 V10 quattro          FirstRegMonth                    7
# 4020   RS6 Avant 5.0 V10 quattro      ConditionTypeText             Occasion
# 17751  RS6 Avant 5.0 V10 quattro           BodyTypeText                Kombi
# 19498  RS6 Avant 5.0 V10 quattro   TransmissionTypeText  Automat sequentiell
# 12557  RS6 Avant 5.0 V10 quattro           FuelTypeText               Benzin
# 10620  RS6 Avant 5.0 V10 quattro                    Ccm                 4991
# 10794  RS6 Avant 5.0 V10 quattro                     Km                25400
# 6316   RS6 Avant 5.0 V10 quattro  ConsumptionRatingText                    G
# 10043  RS6 Avant 5.0 V10 quattro                  Doors                    5
# 11363  RS6 Avant 5.0 V10 quattro          DriveTypeText               Allrad
# 11584  RS6 Avant 5.0 V10 quattro             Properties             "Ab MFK"
# 9386   RS6 Avant 5.0 V10 quattro                  Seats                    5
# 1220           RS6 Avant quattro                   City               Zuzwil
# 18137          RS6 Avant quattro      ConditionTypeText             Occasion
# 19250          RS6 Avant quattro   TransmissionTypeText  Automat sequentiell
# 19725          RS6 Avant quattro                  Doors                    5
# 21456          RS6 Avant quattro          BodyColorText            anthrazit
# 1375           RS6 Avant quattro                     Km                38500
# 20198          RS6 Avant quattro   ConsumptionTotalText         14.6 l/100km
# 21434          RS6 Avant quattro  ConsumptionRatingText                    G
# 18184          RS6 Avant quattro           FuelTypeText               Benzin
# 6044           RS6 Avant quattro          DriveTypeText               Allrad
# 17122          RS6 Avant quattro           FirstRegYear                 2002
# 6157           RS6 Avant quattro           BodyTypeText                Kombi
# 4828           RS6 Avant quattro             Properties             "Ab MFK"
# 4091           RS6 Avant quattro                    Ccm                 4172
# 21891          RS6 Avant quattro        Co2EmissionText             350 g/km
# 123            RS6 Avant quattro      InteriorColorText                beige
# 5559           RS6 Avant quattro                  Seats                    5
# 14351          RS6 Avant quattro                     Hp                  450
# 20198  b9cfd044-d037-4814-9511-7814c66a6d14
# 21434  9d245602-3acd-48c4-be40-d83f496ccb39
# 18184  4e952dce-8ddf-4284-a1c9-9ae6d424e534
# 6044   66d965e5-9fcf-4790-a1a4-d1f4c9549bc9
# 17122  8b23fb3b-1e19-432b-a51c-2e06cfda5270
# 6157   7b11d3cc-5925-449d-87fe-87ea15447200
# 4828   89134cec-d2e9-412f-8ff4-633042cbebac
# 4091   0440c088-2dfa-4d70-b0bc-538fd791889a
# 21891  fc96b9e8-739d-420f-82d9-4660f7410c28
# 123    1543adb2-ff80-4ec0-93e5-c84063bf6eb5
# 5559   13c631a2-07d5-4124-9313-e247777be2e8
# 14351  817a6e31-f985-49c1-a2cf-a2dd8a55d4b9
# 6520   c35ed5de-1a74-46ef-8048-0e40d7dc2085
# 8312   12328723-a7df-490c-b43e-ea41092179fc
# 13033  8a558f62-5516-47c1-942e-32d055c40a12
# 15653  7541f429-29cd-4ebe-a4fa-0aca151b973d

# %% [markdown]
# ## Check what the Target Data looks like

# %%
t_data = pd.read_excel('Target Data.xlsx')
t_data.head()
# Out:
#                   carType  color           condition currency drive  \
# 0  Convertible / Roadster  White                Used      USD   LHD
# 1  Convertible / Roadster  Other  Original Condition      USD   LHD
# 2  Convertible / Roadster  White                Used      USD   LHD
# 3  Convertible / Roadster   Blue                Used      USD   LHD
# 4  Convertible / Roadster  Black  Original Condition      USD   LHD
#
#             city country         make  manufacture_year  mileage mileage_unit  \
# 0         Zuzwil      CH       Toyota              1983      0.0    kilometer
# 1         London      GB      Ferrari              2001      0.0         mile
# 2  Scotts Valley      US      Porsche              1989      0.0         mile
# 3         London      GB  Rolls-Royce              1961      0.0    kilometer
# 4      Hong Kong      HK      Gumpert              2010      0.0    kilometer
#
#              model   model_variant  price_on_request type  zip  \
# 0           Celica    2800 i Supra             False  car  NaN
# 1              550             NaN              True  car  NaN
# 2          911 "G"             NaN              True  car  NaN
# 3  Silver Cloud II             NaN             False  car  NaN
# 4           Apollo  Apollo S 800hp             False  car  NaN
#
#    manufacture_month fuel_consumption_unit
# 0                3.0      l_km_consumption
# 1                NaN                   NaN
# 2                NaN                   NaN
# 3                NaN                   NaN
# 4                NaN                   NaN

# %% [markdown]
# ## Pre-processing
# Ineed to transform the supplier data to achieve the same granularity as the target data

# %%
# Some rows in the input data have repeting ID and column values, while only the Attribute Names and Attribute Values change.
# We can group them and then make new columns with all Attribute Names and Attribute Values in single row for each ID

CONSTANT_COLUMNS = ["ID", "MakeText", "TypeName", "TypeNameFull", "ModelText", "ModelTypeText"]

# define function to aggragate attributes
def aggregate_attributes(row):
    attr = {key: value for key, value in zip(row["Attribute Names"], row["Attribute Values"])}
    attr.update({col_name: row[col_name] for col_name in CONSTANT_COLUMNS})
    return pd.Series(attr)

# aggregare input data to create one row per product
agg_data = df.groupby(CONSTANT_COLUMNS).agg(
    {"Attribute Names": list, "Attribute Values": list}
).reset_index().apply(aggregate_attributes, axis=1)

agg_data.head(60)
# Out:
# 49          Occasion                     G         21.3 l/100km     2
# 50          Occasion                     G         12.0 l/100km     5
# 51          Occasion                  null                 null     2
# 52          Occasion                     G         14.4 l/100km     2
# 53          Occasion                  null         14.2 l/100km     4
# 54          Occasion                  null                 null     2
# 55          Occasion                     G         14.2 l/100km     2
# 56          Occasion                     G         12.9 l/100km     2
# 57          Occasion                     G         14.6 l/100km     5
# 58          Occasion                     G         13.9 l/100km     5
# 59          Occasion                     G         14.7 l/100km     2
#
#        DriveTypeText  ... InteriorColorText      Km       MakeText  \
# 0             Allrad  ...              grau   31900  MERCEDES-BENZ
# 1             Allrad  ...              null   25400           AUDI
# 2             Allrad  ...             beige   38500           AUDI
# 3   Hinterradantrieb  ...           schwarz     200      CHEVROLET
# 4             Allrad  ...           schwarz    2900        PORSCHE
# 5   Hinterradantrieb  ...           schwarz   92000     FORD (USA)
# 6   Hinterradantrieb  ...           schwarz  120900  MERCEDES-BENZ
# 7   Hinterradantrieb  ...           schwarz   31800   ASTON MARTIN
# 8   Hinterradantrieb  ...         anthrazit   38200          LOTUS
# 9             Allrad  ...           schwarz   26500            BMW
# 10  Hinterradantrieb  ...        mehrfarbig   54000        PORSCHE
# 11  Vorderradantrieb  ...        mehrfarbig  120200           AUDI
# 12            Allrad  ...              grau   99900     LAND ROVER
# 13  Hinterradantrieb  ...              grau   16500  MERCEDES-BENZ
# 14            Allrad  ...             beige   63200     LAND ROVER
# 15  Hinterradantrieb  ...           schwarz   12100  MERCEDES-BENZ
# 16  Hinterradantrieb  ...        mehrfarbig  146500     BMW-ALPINA
# 17  Hinterradantrieb  ...           schwarz   47000  MERCEDES-BENZ
# 18            Allrad  ...           schwarz   27900           AUDI
# 19  Hinterradantrieb  ...           schwarz   19200        RENAULT
# 20            Allrad  ...           schwarz  121000        PORSCHE
# 21            Allrad  ...           schwarz   32800           AUDI
# 22  Hinterradantrieb  ...              grau   48700  MERCEDES-BENZ
# 23  Hinterradantrieb  ...              blau  112500        BENTLEY
# 24  Hinterradantrieb  ...           schwarz   89500        PORSCHE
# 25  Hinterradantrieb  ...           schwarz   48300  MERCEDES-BENZ
# 26            Allrad  ...           schwarz   47600        PORSCHE
# 27            Allrad  ...           schwarz  125400           AUDI
# 28  Hinterradantrieb  ...               rot   34500  MERCEDES-BENZ
# 29  Hinterradantrieb  ...           schwarz   97300  MERCEDES-BENZ
# 30  Hinterradantrieb  ...             beige   95400  MERCEDES-BENZ
# 31  Hinterradantrieb  ...             braun  153600        RENAULT
# 32            Allrad  ...               rot   16200    LAMBORGHINI
# 33            Allrad  ...           schwarz   36700        PORSCHE
# 34  Hinterradantrieb  ...           schwarz   46000  MERCEDES-BENZ
# 35  Hinterradantrieb  ...           schwarz   49900  MERCEDES-BENZ
# 36  Hinterradantrieb  ...             braun   19100  MERCEDES-BENZ
# 37            Allrad  ...           schwarz   40500            BMW
# 38  Hinterradantrieb  ...              blau   34000  MERCEDES-BENZ
# 39  Hinterradantrieb  ...         anthrazit   32000  MERCEDES-BENZ
# 40            Allrad  ...              grau  185900           AUDI
# 41            Allrad  ...           schwarz   16000    LAMBORGHINI
# 42  Hinterradantrieb  ...         anthrazit   81900            BMW
# 43  Hinterradantrieb  ...           schwarz   38000        TRIUMPH
# 44              null  ...           schwarz  130000        LINCOLN
# 45            Allrad  ...           schwarz   43400           AUDI
# 46  Hinterradantrieb  ...              grau   46500        FERRARI
# 47  Hinterradantrieb  ...           schwarz   51000  MERCEDES-BENZ
# 48            Allrad  ...           schwarz   49900     LAND ROVER
# 49            Allrad  ...           schwarz   33000    LAMBORGHINI
# 50            Allrad  ...             weiss   50000           AUDI
# 51  Hinterradantrieb  ...        mehrfarbig  108000        RENAULT
# 52  Hinterradantrieb  ...           schwarz   77700  MERCEDES-BENZ
# 53  Hinterradantrieb  ...              grau   60700            BMW
# 54  Hinterradantrieb  ...        mehrfarbig   49500    LAMBORGHINI
# 55  Hinterradantrieb  ...             beige   59300  MERCEDES-BENZ
# 56  Hinterradantrieb  ...           schwarz   61300        PORSCHE
# 57            Allrad  ...             beige   75200           AUDI
# 58            Allrad  ...        mehrfarbig  127700         HUMMER
# 59  Hinterradantrieb  ...           schwarz   29500  MERCEDES-BENZ
#
#             ModelText                     ModelTypeText  \
# 0               E 320            E 320 Elégance 4-Matic
# 1                 RS6         RS6 Avant 5.0 V10 quattro
# 2                 RS6                 RS6 Avant quattro
# 3            CORVETTE                      Corvette Z06
# 4             CAYENNE  Cayenne Turbo Techart Magnum Kit
# 5             MUSTANG              Mustang Shelby GT500
# 6             CLS 500                           CLS 500
# 7                 DB9                       DB9 Volante
# 8               ELISE                             Elise
# 9                  X5                          X5 4.6is
# 10                924                         924 Turbo
# 11          Cabriolet                   Cabriolet 2.8 E
# 12        RANGE ROVER             Range Rover 3.6 d HSE
# 13          SL 55 AMG                         SL 55 AMG
# 14        RANGE ROVER           Range Rover 4.4TD Vogue
# 15           C 63 AMG     C 63 AMG BLACK SERIES (Coupé)
# 16           3 SERIES                       3 SERIES B8
# 17          SL 55 AMG                         SL 55 AMG
# 18                RS6                 RS6 Avant quattro
# 19        Alpine A110   Alpine A110 1600S Gruppe 5 look
# 20            CAYENNE                     Cayenne Turbo
# 21                RS6         RS6 Avant 5.0 V10 quattro
# 22             SL 600                            SL 600
# 23              TURBO                           Turbo R
# 24                911                       911 Carrera
# 25             SL 500                            SL 500
# 26                911                         911 Turbo
# 27                 A8                    A8 4.2 quattro
# 28                SLR                         SLR 730PS
# 29           S 65 AMG                        S 65 AMG L
# 30            CLS 500                           CLS 500
# 31             ALPINE                    Alpine A310 V6
# 32         MURCIÉLAGO           Murciélago 6.2 Roadster
# 33            CAYENNE                     Cayenne Turbo
# 34           S 65 AMG             S 65 L / BRABUS T65 S
# 35           E 55 AMG               E 55 AMG Avantgarde
# 36         CLS 63 AMG                        CLS 63 AMG
# 37                 X5                           X5 4.4i
# 38             SL 500                            SL 500
# 39          SL 55 AMG                         SL 55 AMG
# 40                 S4                  S4 Avant quattro
# 41         MURCIÉLAGO              Murciélago 6.2 Coupé
# 42                330                             330Ci
# 43           Spitfire                    Spitfire MK IV
# 44          Navigator                    Navigator 32 V
# 45                RS6                 RS6 Avant quattro
# 46                456                           456M GT
# 47            CLS 500                           CLS 500
# 48  RANGE ROVER SPORT       Range Rover Sport 4.2 V8 SC
# 49         MURCIÉLAGO            Murciélago LP640-4 Cpé
# 50                RS4                 RS4 Avant quattro
# 51             ALPINE                    Alpine A310 V6
# 52             SL 600                            SL 600
# 53                750                              750i
# 54             DIABLO                        Diablo 5.7
# 55          SL 55 AMG                         SL 55 AMG
# 56                911                           911 GT2
# 57                RS6                 RS6 Avant quattro
# 58                 H3                     H3 3.5 Luxury
# 59             CL 600                            CL 600
#
#                             Properties Seats            TransmissionTypeText  \
# 0                             "Ab MFK"     5                         Automat
# 1                             "Ab MFK"     5             Automat sequentiell
# 2                             "Ab MFK"     5             Automat sequentiell
# 3   "Ab MFK", "Direkt-/Parallelimport"     2          Schaltgetriebe manuell
# 4                             "Ab MFK"     5             Automat sequentiell
# 5   "Ab MFK", "Direkt-/Parallelimport"     4                  Schaltgetriebe
# 6                             "Ab MFK"     4             Automat sequentiell
# 7                             "Ab MFK"     4             Automat sequentiell
# 8                             "Ab MFK"     2          Schaltgetriebe manuell
# 9                             "Ab MFK"     5             Automat sequentiell
# 10                            "Ab MFK"     4          Schaltgetriebe manuell
# 11                            "Ab MFK"     4                         Automat
# 12                            "Ab MFK"     5                         Automat
# 13                            "Ab MFK"     2                         Automat
# 14  "Ab MFK", "Direkt-/Parallelimport"     5             Automat sequentiell
# 15                            "Ab MFK"     2              Automatik-Getriebe
# 16                            "Ab MFK"     5                  Schaltgetriebe
# 17                            "Ab MFK"     2             Automat sequentiell
# 18                            "Ab MFK"     5             Automat sequentiell
# 19                         "Rennwagen"     2                  Schaltgetriebe
# 20                            "Ab MFK"     5             Automat sequentiell
# 21                  "Ab MFK", "Tuning"     5             Automat sequentiell
# 22                            "Ab MFK"     2                         Automat
# 23                            "Ab MFK"     5                         Automat
# 24                            "Ab MFK"     4                         Automat
# 25                            "Ab MFK"     0                         Automat
# 26                  "Ab MFK", "Tuning"     4          Schaltgetriebe manuell
# 27                                null     5                         Automat
# 28                  "Ab MFK", "Tuning"     2              Automatik-Getriebe
# 29                            "Ab MFK"     5             Automat sequentiell
# 30                            "Ab MFK"     4             Automat sequentiell
# 31                            "Ab MFK"     4          Schaltgetriebe manuell
# 32                            "Ab MFK"     2              Automatik-Getriebe
# 33                            "Ab MFK"     5             Automat sequentiell
# 34                            "Ab MFK"     5             Automat sequentiell
# 35                            "Ab MFK"     5                         Automat
# 36                            "Ab MFK"     4             Automat sequentiell
# 37                            "Ab MFK"     5             Automat sequentiell
# 38                            "Ab MFK"     0                         Automat
# 39                            "Ab MFK"     2                         Automat
# 40                            "Ab MFK"     5          Schaltgetriebe manuell
# 41                            "Ab MFK"     2          Schaltgetriebe manuell
# 42                            "Ab MFK"     5              Automatik-Getriebe
# 43                            "Ab MFK"     2                  Schaltgetriebe
# 44                            "Ab MFK"     7              Automatik-Getriebe
# 45                            "Ab MFK"     5             Automat sequentiell
# 46                            "Ab MFK"     4          Schaltgetriebe manuell
# 47                            "Ab MFK"     4             Automat sequentiell
# 48                                null     5                         Automat
# 49                            "Ab MFK"     2  Automatisiertes Schaltgetriebe
# 50                            "Ab MFK"     5          Schaltgetriebe manuell
# 51                            "Ab MFK"     4          Schaltgetriebe manuell
# 52                            "Ab MFK"     2                         Automat
# 53                            "Ab MFK"     5             Automat sequentiell
# 54                            "Ab MFK"     2          Schaltgetriebe manuell
# 55                            "Ab MFK"     2                         Automat
# 56                  "Ab MFK", "Tuning"     4          Schaltgetriebe manuell
# 57                  "Ab MFK", "Tuning"     5             Automat sequentiell
# 58                            "Ab MFK"     5                         Automat
# 59                            "Ab MFK"     4                         Automat
#
#                             TypeName  \
# 0             E 320 Elégance 4-Matic
# 1          RS6 Avant 5.0 V10 quattro
# 2                  RS6 Avant quattro
# 3                       Corvette Z06
# 4   Cayenne Turbo Techart Magnum Kit
# 5                       Shelby GT500
# 6                            CLS 500
# 7                        DB9 Volante
# 8                              Elise
# 9                           X5 4.6is
# 10                             Turbo
# 11                   Cabriolet 2.8 E
# 12             Range Rover 3.6 d HSE
# 13                         SL 55 AMG
# 14           Range Rover 4.4TD Vogue
# 15              BLACK SERIES (Coupé)
# 16                                B8
# 17                         SL 55 AMG
# 18                 RS6 Avant quattro
# 19               1600S Gruppe 5 look
# 20                     Cayenne Turbo
# 21         RS6 Avant 5.0 V10 quattro
# 22                            SL 600
# 23                           Turbo R
# 24                       911 Carrera
# 25                            SL 500
# 26                         911 Turbo
# 27                    A8 4.2 quattro
# 28                             730PS
# 29                        S 65 AMG L
# 30                           CLS 500
# 31                    Alpine A310 V6
# 32           Murciélago 6.2 Roadster
# 33                     Cayenne Turbo
# 34             S 65 L / BRABUS T65 S
# 35               E 55 AMG Avantgarde
# 36                        CLS 63 AMG
# 37                           X5 4.4i
# 38                            SL 500
# 39                         SL 55 AMG
# 40                  S4 Avant quattro
# 41              Murciélago 6.2 Coupé
# 42                             330Ci
# 43                             MK IV
# 44                              32 V
# 45                 RS6 Avant quattro
# 46                           456M GT
# 47                           CLS 500
# 48       Range Rover Sport 4.2 V8 SC
# 49            Murciélago LP640-4 Cpé
# 50                 RS4 Avant quattro
# 51                    Alpine A310 V6
# 52                            SL 600
# 53                              750i
# 54                        Diablo 5.7
# 55                         SL 55 AMG
# 56                           911 GT2
# 57                 RS6 Avant quattro
# 58                     H3 3.5 Luxury
# 59                            CL 600
#
#                                    TypeNameFull
# 0          MERCEDES-BENZ E 320 Elégance 4-Matic
# 1                AUDI RS6 Avant 5.0 V10 quattro
# 2                        AUDI RS6 Avant quattro
# 3                        CHEVROLET Corvette Z06
# 4      PORSCHE Cayenne Turbo Techart Magnum Kit
# 5               FORD (USA) Mustang Shelby GT500
# 6                         MERCEDES-BENZ CLS 500
# 7                      ASTON MARTIN DB9 Volante
# 8                                   LOTUS Elise
# 9                                  BMW X5 4.6is
# 10                            PORSCHE 924 Turbo
# 11                         AUDI Cabriolet 2.8 E
# 12             LAND ROVER Range Rover 3.6 d HSE
# 13                      MERCEDES-BENZ SL 55 AMG
# 14           LAND ROVER Range Rover 4.4TD Vogue
# 15  MERCEDES-BENZ C 63 AMG BLACK SERIES (Coupé)
# 16                       BMW-ALPINA 3 SERIES B8
# 17                      MERCEDES-BENZ SL 55 AMG
# 18                       AUDI RS6 Avant quattro
# 19      RENAULT Alpine A110 1600S Gruppe 5 look
# 20                        PORSCHE Cayenne Turbo
# 21               AUDI RS6 Avant 5.0 V10 quattro
# 22                         MERCEDES-BENZ SL 600
# 23                              BENTLEY Turbo R
# 24                          PORSCHE 911 Carrera
# 25                         MERCEDES-BENZ SL 500
# 26                            PORSCHE 911 Turbo
# 27                          AUDI A8 4.2 quattro
# 28                      MERCEDES-BENZ SLR 730PS
# 29                     MERCEDES-BENZ S 65 AMG L
# 30                        MERCEDES-BENZ CLS 500
# 31                       RENAULT Alpine A310 V6
# 32          LAMBORGHINI Murciélago 6.2 Roadster
# 33                        PORSCHE Cayenne Turbo
# 34          MERCEDES-BENZ S 65 L / BRABUS T65 S
# 35            MERCEDES-BENZ E 55 AMG Avantgarde
# 36                     MERCEDES-BENZ CLS 63 AMG
# 37                                  BMW X5 4.4i
# 38                         MERCEDES-BENZ SL 500
# 39                      MERCEDES-BENZ SL 55 AMG
# 40                        AUDI S4 Avant quattro
# 41             LAMBORGHINI Murciélago 6.2 Coupé
# 42                                    BMW 330Ci
# 43                       TRIUMPH Spitfire MK IV
# 44                       LINCOLN Navigator 32 V
# 45                       AUDI RS6 Avant quattro
# 46                              FERRARI 456M GT
# 47                        MERCEDES-BENZ CLS 500
# 48       LAND ROVER Range Rover Sport 4.2 V8 SC
# 49           LAMBORGHINI Murciélago LP640-4 Cpé
# 50                       AUDI RS4 Avant quattro
# 51                       RENAULT Alpine A310 V6
# 52                         MERCEDES-BENZ SL 600
# 53                                     BMW 750i
# 54                       LAMBORGHINI Diablo 5.7
# 55                      MERCEDES-BENZ SL 55 AMG
# 56                              PORSCHE 911 GT2
# 57                       AUDI RS6 Avant quattro
# 58                         HUMMER H3 3.5 Luxury
# 59                         MERCEDES-BENZ CL 600
#
# [60 rows x 25 columns]

# %% [markdown]
# ### Have a look at the Attribute Names

# %%
pd.DataFrame(Counter(df["Attribute Names"]), index=["Attribute Names"])
# Out:
#                    Km  InteriorColorText  BodyColorText  Properties  \
# Attribute Names  1153               1153           1153        1153
#
#                  ConsumptionTotalText    Hp   Ccm  BodyTypeText  \
# Attribute Names                  1153  1153  1153          1152
#
#                  ConsumptionRatingText  Doors  Seats  ConditionTypeText  \
# Attribute Names                   1153   1153   1153               1153
#
#                  TransmissionTypeText  FuelTypeText  FirstRegYear  City  \
# Attribute Names                  1153          1153          1153  1153
#
#                  FirstRegMonth  Co2EmissionText  DriveTypeText
# Attribute Names           1153             1153           1153

# %% [markdown]
# ## Normalization
# Normalisation is required in case an attribute value is different but actually is the same (different
# spelling, language, different unit used etc.).
#
# E.g. the first column in the target data "carType" defines names

# %%
pd.DataFrame({k: v for k, v in Counter(t_data["carType"]).most_common()}, index=["carType"])
# Out:
#          Coupé  Convertible / Roadster  Other  Saloon  Custom  SUV  NaN  \
# carType   3359                    1970    902     362     200  187  101
#
#          Station Wagon  Targa  Single seater
# carType             90     62             19

# %% [markdown]
# The column BodyTypeText in the input data can be used as carTypes for the target data but it uses slightly different carType names (some in German) and some are missgng (e.g. Single seater)

# %%
pd.DataFrame({k: v for k, v in Counter(agg_data["BodyTypeText"]).most_common()}, index=["BodyTypeText"])
# Out:
#               Coupé  Limousine  Cabriolet  Kombi  SUV / Geländewagen  \
# BodyTypeText    348        313        236     98                  88
#
#               Kleinwagen  Kompaktvan / Minivan  Pick-up  Sattelschlepper
# BodyTypeText          12                     4        3                1

# %% [markdown]
# One could use the number of seats to find the "Single seater" cars for the target data

# %%
pd.DataFrame({k: v for k, v in Counter(agg_data["Seats"]).most_common()}, index=["Seats"])
# Out:
#          5    2    4   0  3  7  1  6
# Seats  473  303  287  31  3  2  2  2

# %% [markdown]
# ### Normalize column "carType"

# %% [markdown]
# it is neccessary to change the names of the car types found in BodyTypeText column of the input data to match the names used in Target Data carType column and use the number of seats to find the "Single seater".
# If the BodyType in input data can't be assigned to one of the types in target data, put it to "Other"

# %%
def normalize_cartype(row):
    if row["Seats"] == 1:
        return "Single seater"
    try:
        return {
            "Coupé": "Coupé",
            "Limousine": "Saloon",
            "Cabriolet": "Convertible / Roadster",
            "Kombi": "Station Wagon",
            "SUV / Geländewagen": "SUV",
        }[row["BodyTypeText"]]
    except KeyError:
        return "Other"

# %% [markdown]
# ### Normalize column "color"
# the same as with carType. Some color are in German and some are slightly different. Assign them to standard values from target data

# %%
pd.DataFrame({k: v for k, v in Counter(t_data["color"]).most_common()}, index=["color"])
# Out:
#        Other   Red  Black  Blue  Silver  White  Gray  Green  Yellow  Beige  \
# color   1433  1207    942   840     678    671   501    454     204     99
#
#        Orange  Brown  Gold  Purple
# color      88     75    35      25

# %%
pd.DataFrame({k: v for k, v in Counter(agg_data["BodyColorText"]).most_common()}, index=["BodyColorText"])
# Out:
#                schwarz mét.  silber mét.  blau mét.  grau mét.  schwarz  \
# BodyColorText           223          200        108         98       92
#
#                weiss  rot  grün mét.  blau  anthrazit mét.  ...  beige mét.  \
# BodyColorText     62   58         45    39              29  ...           4
#
#                bordeaux  gold mét.  braun mét.  orange  orange mét.  beige  \
# BodyColorText         3          3           2       2            2      1
#
#                braun  gelb mét.  gold
# BodyColorText      1          1     1
#
# [1 rows x 29 columns]

# %%
def normalize_color(row):
    for english, germans in [
            ("Black", ["schwarz"]), ("Silver", ["silber"]), ("Blue", ["blau"]), ("Gray", ["grau", "anthrazit"]), ("White", ["weiss"]),
            ("Red", ["red", "bordeaux"]), ("Green", ["grün"]), ("Yellow", ["gelb"]), ("Purple", ["violett"]),
            ("Gold", ["gold"]), ("Brown", ["braun"]), ("Orange", ["orange"]), ("Beige", ["beige"])]:
        for german in germans:
            if german in row["BodyColorText"]:
                return english
    return "Other"

# %% [markdown]
# ### Normalize column ConditionTypeText

# %%
pd.DataFrame({k: v for k, v in Counter(agg_data["ConditionTypeText"]).most_common()}, index=["ConditionTypeText"])
# Out:
#                    Occasion  Oldtimer  Neu  Vorführmodell
# ConditionTypeText      1059        18   17              9

# %%
pd.DataFrame({k: v for k, v in Counter(t_data["condition"]).most_common()}, index=["condition"])
# Out:
#            Used  Restored  Original Condition  Used with guarantee  New  \
# condition  5190      1005                 744                  162  108
#
#            Restoration Project
# condition                   43

# %%
def normalize_condition(row):
    try:
        return {
            "Occasion": "Used",
            "Oldtimer": "Restored",
            "Neu": "New",
            "Vorführmodell": "Original Condition",
        }[row["ConditionTypeText"]]
    except KeyError:
        return "Other"

# %% [markdown]
# ### Normalize columns model and model_variant
# In order to extract  variant  without  model, we can remove  model  from the column ModelTypeText. If this doesn't work, we use TypeName as a fallback. Note: When there is no variant, this will result in an empty string.

# %%
pd.DataFrame({k: v for k, v in Counter(agg_data["MakeText"]).most_common()}, index=["MakeText"])
# Out:
#           MERCEDES-BENZ  PORSCHE  BMW  AUDI  FERRARI  RENAULT  LAMBORGHINI  \
# MakeText            285      137  124   118       68       45           36
#
#           BENTLEY  MASERATI  VW  ...  BUGATTI  TALBOT  LEXUS  HYUNDAI  SMART  \
# MakeText       34        32  19  ...        1       1      1        1      1
#
#           WIESMANN  DATSUN  DE TOMASO  AUTOBIANCHI  MINI
# MakeText         1       1          1            1     1
#
# [1 rows x 56 columns]

# %%
pd.DataFrame({k: v for k, v in Counter(agg_data["ModelText"]).most_common()}, index=["ModelText"])
# Out:
#            911  RS6  SL 500  CAYENNE  SL 600  SL 55 AMG  ALPINE  A8  M5  \
# ModelText   95   58      33       27      21         18      18  17  16
#
#            CONTINENTAL  ...  ML 350  PANTERA  A112  Silverado  MX-5  205  \
# ModelText           15  ...       1        1     1          1     1    1
#
#            XJ 220  ESPACE  MINI  A 150
# ModelText       1       1     1      1
#
# [1 rows x 290 columns]

# %%
pd.DataFrame({k: v for k, v in Counter(agg_data["ModelTypeText"]).most_common()}, index=["ModelTypeText"])
# Out:
#                RS6 Avant quattro  SL 500  911 Turbo  \
# ModelTypeText                 31      30         30
#
#                RS6 Avant 5.0 V10 quattro  SL 600  SL 55 AMG  Cayenne Turbo  \
# ModelTypeText                         23      21         18             18
#
#                M5  A8 4.2 quattro  CL 600  ...  H3 3.7 Adventure  \
# ModelTypeText  16              15      12  ...                 1
#
#                Alpine A110 1300 VC Gordini  MX-5 1.8i 16V Confort  \
# ModelTypeText                            1                      1
#
#                205 Turbo 16V  320d xDrive M-Sportpaket  XJ 220  \
# ModelTypeText              1                         1       1
#
#                Espace 2.0 T Privilège  1000  MP4-12C Cabriolet 3.8 V8  \
# ModelTypeText                       1     1                         1
#
#                A 150 Classic
# ModelTypeText              1
#
# [1 rows x 548 columns]

# %%
pd.DataFrame({k: v for k, v in Counter(agg_data["TypeName"]).most_common()}, index=["TypeName"])
# Out:
#           RS6 Avant quattro  SL 500  911 Turbo  RS6 Avant 5.0 V10 quattro  \
# TypeName                 31      30         29                         23
#
#           SL 600  SL 55 AMG  Cayenne Turbo  null  M5  A8 4.2 quattro  ...  \
# TypeName      21         18             18    16  16              15  ...
#
#           Alpine V6 Turbo  H3 3.7 Adventure  1300 VC Gordini  \
# TypeName                1                 1                1
#
#           MX-5 1.8i 16V Confort  Turbo 16V  320d xDrive M-Sportpaket  \
# TypeName                      1          1                         1
#
#           Espace 2.0 T Privilège  1000  MP4-12C Cabriolet 3.8 V8  \
# TypeName                       1     1                         1
#
#           A 150 Classic
# TypeName              1
#
# [1 rows x 531 columns]

# %%
def normalize_variant(row):
    model = row["ModelText"].strip()
    model_variant = row["ModelTypeText"].strip()
    if model_variant[:len(model)].lower() == model.lower():
        return model_variant[len(model):].strip()
    return row["TypeName"]

# %% [markdown]
# ### Normalize column Zip
# Can be done with e.g. pyzipcode.

# %%
pd.DataFrame({k: v for k, v in Counter(agg_data["City"]).most_common()}, index=["City"])
# Out:
#       Zuzwil  Porrentruy  Sursee  Safenwil  Basel  St. Gallen
# City    1072          13       9         4      3           2

# %%
pd.DataFrame({k: v for k, v in Counter(t_data["city"]).most_common()}, index=["city"])
# Out:
#       Zuzwil  De Lier  Bovenden  Aalter  London  NaN  BRUMMEN  Singen  Paris  \
# city     675      513       338     243     221  218      208     191    176
#
#       Waalwijk  ...  market harborough  St. Gallen  Sydney  Perth  Dortmund  \
# city       159  ...                  1           1       1      1         1
#
#       97447 Gerolzhofen  Aubussargues  Milano  Dubai - United Arab Emirates  \
# city                  1             1       1                             1
#
#       PADOVA
# city       1
#
# [1 rows x 417 columns]

# %%
def normalize_zip(row):
    try:
        return {
            "Zuzwil": "9524",
            "Porrentruy": "2900",
            "Sursee": "6210",
            "Safenwil": "5745",
            "Basel": "4000",
            "St. Galen": "9000",
        }[row["City"]]
    except KeyError:
        return "Other"

# %% [markdown]
# ## Perform normalization of all columns posible to normalize

# %%
NORM_FUNCTIONS = {
    "BodyTypeText": normalize_cartype,
    "BodyColorText": normalize_color,
    "Condition": normalize_condition,
    "Variant": normalize_variant,
    "Zip": normalize_zip,

}

def normalize(row):
    for column, funct in NORM_FUNCTIONS.items():
        row[column] = funct(row)
    return row
    
normalized_data = agg_data.apply(normalize, axis=1)
normalized_data.head()
# Out:
#   BodyColorText   BodyTypeText   Ccm    City Co2EmissionText  \
# 0          Gray         Saloon  3199  Zuzwil        275 g/km
# 1          Gray  Station Wagon  4991  Zuzwil        333 g/km
# 2          Gray  Station Wagon  4172  Zuzwil        350 g/km
# 3          Gray          Coupé  6162  Zuzwil        291 g/km
# 4          Gray            SUV  4806  Zuzwil        270 g/km
#
#   ConditionTypeText ConsumptionRatingText ConsumptionTotalText Doors  \
# 0          Occasion                  null         11.5 l/100km     4
# 1          Occasion                     G         14.0 l/100km     5
# 2          Occasion                     G         14.6 l/100km     5
# 3          Occasion                     G         12.7 l/100km     2
# 4          Occasion                     G         11.5 l/100km     5
#
#       DriveTypeText  ... ModelText                     ModelTypeText  \
# 0            Allrad  ...     E 320            E 320 Elégance 4-Matic
# 1            Allrad  ...       RS6         RS6 Avant 5.0 V10 quattro
# 2            Allrad  ...       RS6                 RS6 Avant quattro
# 3  Hinterradantrieb  ...  CORVETTE                      Corvette Z06
# 4            Allrad  ...   CAYENNE  Cayenne Turbo Techart Magnum Kit
#
#                            Properties Seats    TransmissionTypeText  \
# 0                            "Ab MFK"     5                 Automat
# 1                            "Ab MFK"     5     Automat sequentiell
# 2                            "Ab MFK"     5     Automat sequentiell
# 3  "Ab MFK", "Direkt-/Parallelimport"     2  Schaltgetriebe manuell
# 4                            "Ab MFK"     5     Automat sequentiell
#
#                            TypeName                              TypeNameFull  \
# 0            E 320 Elégance 4-Matic      MERCEDES-BENZ E 320 Elégance 4-Matic
# 1         RS6 Avant 5.0 V10 quattro            AUDI RS6 Avant 5.0 V10 quattro
# 2                 RS6 Avant quattro                    AUDI RS6 Avant quattro
# 3                      Corvette Z06                    CHEVROLET Corvette Z06
# 4  Cayenne Turbo Techart Magnum Kit  PORSCHE Cayenne Turbo Techart Magnum Kit
#
#   Condition                   Variant   Zip
# 0      Used          Elégance 4-Matic  9524
# 1      Used     Avant 5.0 V10 quattro  9524
# 2      Used             Avant quattro  9524
# 3      Used                       Z06  9524
# 4      Used  Turbo Techart Magnum Kit  9524
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Perform integration

# %%
def integrate(row):
    return pd.Series({
        "carType": row["BodyTypeText"],
        "color": row["BodyColorText"],
        "condition": row["ConditionTypeText"],
        "currency": "CHF", # assume all cars are from/to be sold CH
        "drive": "LHD", # all cars in the input data are from CH, hence LHD, could not find column to normalize
        "city": row["City"], # all cities are from CH
        "country": "CH", # all cars in the input data are from CH but can be deduced from the city name
        "make": row["MakeText"],
        "manufacture_year": row["FirstRegYear"],
        "mileage": row["Km"], 
        "mileage_unit": "kilometer", # all cars are form CH
        "model": row["ModelText"],
        "model_variant": row["Variant"], 
        "price_on_request": None, # could not find column to normalize in the input data
        "type": "car", # all of target data contains the value "car"
        "zip": row["Zip"], # can be inferred from city using e.g pgeocode
        "manufacture_month": row["FirstRegMonth"],
        "fuel_consumption_unit": "l_km_consumption" if row["ConsumptionTotalText"] and row["ConsumptionTotalText"] != 'null' else None,
    })

formated_data = normalized_data.apply(integrate, axis=1)
formated_data.head(100)
# Out:
#                    carType color condition currency drive    city country  \
# 0                   Saloon  Gray  Occasion      CHF   LHD  Zuzwil      CH
# 1            Station Wagon  Gray  Occasion      CHF   LHD  Zuzwil      CH
# 2            Station Wagon  Gray  Occasion      CHF   LHD  Zuzwil      CH
# 3                    Coupé  Gray  Occasion      CHF   LHD  Zuzwil      CH
# 4                      SUV  Gray  Occasion      CHF   LHD  Zuzwil      CH
# ..                     ...   ...       ...      ...   ...     ...     ...
# 95  Convertible / Roadster  Blue  Occasion      CHF   LHD  Zuzwil      CH
# 96                  Saloon  Blue  Occasion      CHF   LHD  Zuzwil      CH
# 97           Station Wagon  Blue  Occasion      CHF   LHD  Zuzwil      CH
# 98                   Coupé  Blue  Occasion      CHF   LHD  Zuzwil      CH
# 99                  Saloon  Blue  Occasion      CHF   LHD  Zuzwil      CH
#
#              make manufacture_year mileage mileage_unit     model  \
# 0   MERCEDES-BENZ             1999   31900    kilometer     E 320
# 1            AUDI             2008   25400    kilometer       RS6
# 2            AUDI             2002   38500    kilometer       RS6
# 3       CHEVROLET             2015     200    kilometer  CORVETTE
# 4         PORSCHE             2010    2900    kilometer   CAYENNE
# ..            ...              ...     ...          ...       ...
# 95        PORSCHE             2009   52000    kilometer       911
# 96           AUDI             2006  108200    kilometer       RS4
# 97           AUDI             2001   57500    kilometer       RS4
# 98        FERRARI             2013   12000    kilometer       F12
# 99           AUDI             2003   26300    kilometer        A8
#
#                model_variant price_on_request type   zip manufacture_month  \
# 0           Elégance 4-Matic             None  car  9524                 1
# 1      Avant 5.0 V10 quattro             None  car  9524                 7
# 2              Avant quattro             None  car  9524                10
# 3                        Z06             None  car  9524                 6
# 4   Turbo Techart Magnum Kit             None  car  9524                 1
# ..                       ...              ...  ...   ...               ...
# 95              Turbo Cabrio             None  car  9524                12
# 96            4.2 V8 quattro             None  car  9524                 5
# 97             Avant quattro             None  car  9524                 7
# 98                Berlinetta             None  car  9524                 1
# 99               4.2 quattro             None  car  9524                11
#
#    fuel_consumption_unit
# 0       l_km_consumption
# 1       l_km_consumption
# 2       l_km_consumption
# 3       l_km_consumption
# 4       l_km_consumption
# ..                   ...
# 95      l_km_consumption
# 96      l_km_consumption
# 97      l_km_consumption
# 98      l_km_consumption
# 99      l_km_consumption
#
# [100 rows x 18 columns]

# %%
t_data.head()
# Out:
#                   carType  color           condition currency drive  \
# 0  Convertible / Roadster  White                Used      USD   LHD
# 1  Convertible / Roadster  Other  Original Condition      USD   LHD
# 2  Convertible / Roadster  White                Used      USD   LHD
# 3  Convertible / Roadster   Blue                Used      USD   LHD
# 4  Convertible / Roadster  Black  Original Condition      USD   LHD
#
#             city country         make  manufacture_year  mileage mileage_unit  \
# 0         Zuzwil      CH       Toyota              1983      0.0    kilometer
# 1         London      GB      Ferrari              2001      0.0         mile
# 2  Scotts Valley      US      Porsche              1989      0.0         mile
# 3         London      GB  Rolls-Royce              1961      0.0    kilometer
# 4      Hong Kong      HK      Gumpert              2010      0.0    kilometer
#
#              model   model_variant  price_on_request type  zip  \
# 0           Celica    2800 i Supra             False  car  NaN
# 1              550             NaN              True  car  NaN
# 2          911 "G"             NaN              True  car  NaN
# 3  Silver Cloud II             NaN             False  car  NaN
# 4           Apollo  Apollo S 800hp             False  car  NaN
#
#    manufacture_month fuel_consumption_unit
# 0                3.0      l_km_consumption
# 1                NaN                   NaN
# 2                NaN                   NaN
# 3                NaN                   NaN
# 4                NaN                   NaN

# %% [markdown]
# ## Export Excel files

# %%
with pd.ExcelWriter("solution.xlsx") as writer:
    agg_data.to_excel(writer, sheet_name="Pre-processed Data", index=False, na_rep="null")
    normalized_data.to_excel(writer, sheet_name="Normalized Data", index=False, na_rep="null")
    formated_data.to_excel(writer, sheet_name="Integrated Data", index=False, na_rep="null")
